# %%
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Read the CSV file into a DataFrame
df = pd.read_csv('USA_Housing.csv')

# Display the first 5 rows
print(df.head().to_markdown(index=False, numalign="left", stralign="left"))

# Print the column names and their data types
print(df.info())
# Out:
# | Avg. Area Income   | Avg. Area House Age   | Avg. Area Number of Rooms   | Avg. Area Number of Bedrooms   | Area Population   | Price       |
# |:-------------------|:----------------------|:----------------------------|:-------------------------------|:------------------|:------------|
# | 79545.5            | 5.68286               | 7.00919                     | 4.09                           | 23086.8           | 1.05903e+06 |
# | 79248.6            | 6.0029                | 6.73082                     | 3.09                           | 40173.1           | 1.50589e+06 |
# | 61287.1            | 5.86589               | 8.51273                     | 5.13                           | 36882.2           | 1.05899e+06 |
# | 63345.2            | 7.18824               | 5.58673                     | 3.26                           | 34310.2           | 1.26062e+06 |
# ...

# %%
new_df = df.drop(columns=["Price"])

# Display the descriptive statistics
print(new_df.describe().to_markdown(numalign="left", stralign="left"))
# Out:
# |       | Avg. Area Income   | Avg. Area House Age   | Avg. Area Number of Rooms   | Avg. Area Number of Bedrooms   | Area Population   |
# |:------|:-------------------|:----------------------|:----------------------------|:-------------------------------|:------------------|
# | count | 5000               | 5000                  | 5000                        | 5000                           | 5000              |
# | mean  | 68583.1            | 5.97722               | 6.98779                     | 3.98133                        | 36163.5           |
# | std   | 10658              | 0.991456              | 1.00583                     | 1.23414                        | 9925.65           |
# | min   | 17796.6            | 2.6443                | 3.23619                     | 2                              | 172.611           |
# | 25%   | 61480.6            | 5.32228               | 6.29925                     | 3.14                           | 29403.9           |
# ...

# %%
import pandas as pd
import altair as alt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

df = pd.read_csv('USA_Housing.csv')

# Apply the StandardScaler
new_df = df.drop(columns=["Price"])
scaler = StandardScaler()
scaled_df = scaler.fit_transform(new_df)

# Find the optimal value of k using the Elbow method
inertia = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(scaled_df)
    inertia.append(kmeans.inertia_)

# Plot the inertia for different values of k
elbow_data = pd.DataFrame({'k': range(1, 11), 'Inertia': inertia})

elbow_plot = alt.Chart(elbow_data).mark_line(point=True).encode(
    x='k:O',
    y='Inertia',
    tooltip=['k', 'Inertia']
).properties(
    title='Elbow Method for Optimal k'
).interactive()

# Save the plot
elbow_plot.save('elbow_method_plot.json')
